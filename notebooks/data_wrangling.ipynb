# %%
import re
import os
import glob
import zipfile
import requests
from urllib.request import urlretrieve
import json
import pandas as pd

# %%
with open('/srv/data/my_shared_data_folder/credential.json') as f:
    aws_credentials = json.load(f)

# %%
df = pd.read_parquet('s3://mds-s3-group20/combined_model_data_parti.parquet', 
                     storage_options = aws_credentials)

# %%
df.head()
# Out:
#                  time  lat_min  lat_max  lon_min  lon_max  rain (mm/day)  \
# 0 1889-01-01 12:00:00   -36.25    -35.0  140.625    142.5   3.293256e-13
# 1 1889-01-02 12:00:00   -36.25    -35.0  140.625    142.5   0.000000e+00
# 2 1889-01-03 12:00:00   -36.25    -35.0  140.625    142.5   0.000000e+00
# 3 1889-01-04 12:00:00   -36.25    -35.0  140.625    142.5   0.000000e+00
# 4 1889-01-05 12:00:00   -36.25    -35.0  140.625    142.5   1.047658e-02
#
#         model
# 0  ACCESS-CM2
# 1  ACCESS-CM2
# 2  ACCESS-CM2
# 3  ACCESS-CM2
# 4  ACCESS-CM2

# %%
rain = pd.read_csv('s3://mds-s3-group20/observed_daily_rainfall_SYD.csv', storage_options = aws_credentials)
rain["model"] = "observed_rainfall"

# %%
rain.head()
# Out:
#          time  rain (mm/day)              model
# 0  1889-01-01       0.006612  observed_rainfall
# 1  1889-01-02       0.090422  observed_rainfall
# 2  1889-01-03       1.401452  observed_rainfall
# 3  1889-01-04      14.869798  observed_rainfall
# 4  1889-01-05       0.467628  observed_rainfall

# %%
# Query the Sydney data - Expected shape (1150049, 2)
sydney = df.query("lat_min <= -33.86 and lat_max >= -33.86 and lon_min <= 151.21 and lon_max >= 151.21").drop(columns=["lat_min", "lat_max", "lon_min", "lon_max"])

sydney['time'] = pd.to_datetime(sydney["time"]).dt.date
sydney = sydney.set_index('time')
sydney.shape
# Out:
# (1150049, 2)

# %%
# set observed index as time
rain['time'] = pd.to_datetime(rain['time'])
rain.set_index('time', inplace=True)
rain.head()
# Out:
#             rain (mm/day)              model
# time
# 1889-01-01       0.006612  observed_rainfall
# 1889-01-02       0.090422  observed_rainfall
# 1889-01-03       1.401452  observed_rainfall
# 1889-01-04      14.869798  observed_rainfall
# 1889-01-05       0.467628  observed_rainfall

# %%
df_concat = pd.concat([sydney, rain])
df_concat.head()
# Out:
#             rain (mm/day)       model
# time
# 1889-01-01       0.040427  ACCESS-CM2
# 1889-01-02       0.073777  ACCESS-CM2
# 1889-01-03       0.232656  ACCESS-CM2
# 1889-01-04       0.911319  ACCESS-CM2
# 1889-01-05       0.698013  ACCESS-CM2

# %%
pivot_df = (df_concat.reset_index().pivot(index='time', 
                                          columns='model',
                                          values = 'rain (mm/day)')
            .rename_axis(None,axis=1))

pivot_df.shape
# Out:
# (46020, 26)

# %%
pivot_df.head()
# Out:
#             ACCESS-CM2  ACCESS-ESM1-5  AWI-ESM-1-1-LR   BCC-CSM2-MR  \
# time
# 1889-01-01    0.040427       1.814552       35.579336  4.268112e+00
# 1889-01-02    0.073777       0.303965        4.596520  1.190141e+00
# 1889-01-03    0.232656       0.019976        5.927467  1.003845e-09
# 1889-01-04    0.911319      13.623777        8.029624  8.225225e-02
# 1889-01-05    0.698013       0.021048        2.132686  2.496841e+00
#
#                 BCC-ESM1  CMCC-CM2-HR4  CMCC-CM2-SR5  CMCC-ESM2   CanESM5  \
# time
# 1889-01-01  1.107466e-03     11.410537  3.322009e-08   2.668800  1.321215
# 1889-01-02  1.015323e-04      4.014984  1.312700e+00   0.946211  2.788724
# 1889-01-03  1.760345e-05      9.660565  9.103720e+00   0.431999  0.003672
# 1889-01-04  1.808932e-01      3.951528  1.317160e+01   0.368693  0.013578
# 1889-01-05  4.708019e-09      2.766362  1.822940e+01   0.339267  0.002468
#
#             EC-Earth3-Veg-LR  ...  MPI-ESM-1-2-HAM  MPI-ESM1-2-HR  \
# ...

# %%
# Save as a csv file ml_data_SYD.csv to s3://mds-s3-xxx/output/ 
pivot_df.to_csv("s3://mds-s3-group20/output/processed_df.csv",
                storage_options=aws_credentials)

# %%
# Check the csv file was created
pd.read_csv("s3://mds-s3-group20/output/processed_df.csv",
            storage_options=aws_credentials, 
            index_col = 0)
# Out:
#             ACCESS-CM2  ACCESS-ESM1-5  AWI-ESM-1-1-LR   BCC-CSM2-MR  \
# time
# 1889-01-01    0.040427       1.814552    3.557934e+01  4.268112e+00
# 1889-01-02    0.073777       0.303965    4.596520e+00  1.190141e+00
# 1889-01-03    0.232656       0.019976    5.927467e+00  1.003845e-09
# 1889-01-04    0.911319      13.623777    8.029624e+00  8.225225e-02
# 1889-01-05    0.698013       0.021048    2.132686e+00  2.496841e+00
# ...                ...            ...             ...           ...
# 2014-12-27    0.033748       0.123476    1.451179e+00  3.852845e+01
# 2014-12-28    0.094198       2.645496    4.249335e+01  5.833801e-01
# 2014-12-29    0.005964       3.041667    2.898325e+00  9.359547e-02
# 2014-12-30    0.000028       1.131412    2.516381e-01  1.715028e-01
# 2014-12-31    0.532747       2.370896    1.047835e-13  4.437736e+00
#
#                 BCC-ESM1  CMCC-CM2-HR4  CMCC-CM2-SR5  CMCC-ESM2    CanESM5  \
# time
# ...
